# %% [markdown]
# # Get Landing data

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# df = pd.read_csv("./data/csv/5Nov24-flight1.csv")

# df_landing = df[4125:4167]

# plt.plot(df_landing["altitude_ft"])
# plt.show()
# plt.plot(df_landing["speed_kts"])
# plt.show()
# df_landing.to_csv("./data/csv/5Nov24-flight1-landing.csv")

# %%
# df = pd.read_csv("./data/csv/6Nov24-flight2.csv")

# df_landing = df[3824:3860]

# plt.plot(df_landing["altitude_ft"])
# plt.show()
# plt.plot(df_landing["speed_kts"])
# plt.show()

# df_landing.to_csv("./data/csv/6Nov24-flight2-landing.csv")
# df_landing
# Out:
#                     timestamp   latitude   longitude  altitude_m  acc_horiz  \
# 3824  2024-11-06T17:14:41.61Z  40.710624 -114.022533      1298.2        0.0
# 3825  2024-11-06T17:14:42.42Z  40.710811 -114.022774      1297.1        0.0
# 3826  2024-11-06T17:14:43.61Z  40.711247 -114.023339      1294.6        0.0
# 3827  2024-11-06T17:14:44.42Z  40.711434 -114.023582      1293.7        0.0
# 3828  2024-11-06T17:14:45.61Z  40.711870 -114.024151      1292.1        0.0
# 3829  2024-11-06T17:14:46.42Z  40.712056 -114.024396      1291.5        0.0
# 3830  2024-11-06T17:14:47.81Z  40.712550 -114.025056      1290.0        0.0
# 3831  2024-11-06T17:14:48.43Z  40.712736 -114.025304      1289.6        0.0
# 3832  2024-11-06T17:14:49.81Z  40.713172 -114.025879      1288.9        0.0
# 3833  2024-11-06T17:14:50.43Z  40.713359 -114.026124      1288.7        0.0
# 3834  2024-11-06T17:14:51.42Z  40.713548 -114.026368      1288.9        0.0
# ...

# %%
# df = pd.read_csv("./data/csv/6Nov24-flight3.csv")

# df_landing = df[4116:4149]

# plt.plot(df_landing["altitude_ft"])
# plt.show()
# plt.plot(df_landing["speed_kts"])
# plt.show()

# df_landing.to_csv("./data/csv/6Nov24-flight3-landing.csv")
# df_landing
# Out:
#                     timestamp   latitude   longitude  altitude_m  acc_horiz  \
# 4116  2024-11-06T20:42:18.14Z  40.709730 -114.021358      1307.5        0.0
# 4117  2024-11-06T20:42:19.54Z  40.710175 -114.021936      1305.2        0.0
# 4118  2024-11-06T20:42:20.54Z  40.710492 -114.022347      1303.1        0.0
# 4119  2024-11-06T20:42:21.94Z  40.710872 -114.022841      1300.9        0.0
# 4120  2024-11-06T20:42:22.54Z  40.711122 -114.023172      1299.7        0.0
# 4121  2024-11-06T20:42:23.14Z  40.711308 -114.023422      1298.7        0.0
# 4122  2024-11-06T20:42:24.54Z  40.711738 -114.024003      1296.3        0.0
# 4123  2024-11-06T20:42:25.94Z  40.712104 -114.024495      1294.9        0.0
# 4124  2024-11-06T20:42:27.14Z  40.712527 -114.025059      1293.7        0.0
# 4125  2024-11-06T20:42:29.14Z  40.713116 -114.025845      1292.8        0.0
# 4126  2024-11-06T20:42:31.34Z  40.713728 -114.026658      1292.9        0.0
# ...

# %%
# df = pd.read_csv("./data/csv/6Nov24-flight4.csv")

# df_landing = df[3999:4034]

# plt.plot(df_landing["altitude_ft"])
# plt.show()
# plt.plot(df_landing["speed_kts"])
# plt.show()

# df_landing.to_csv("./data/csv/6Nov24-flight4-landing.csv")
# df_landing
# Out:
#                     timestamp   latitude   longitude  altitude_m  acc_horiz  \
# 3999  2024-11-06T23:45:53.00Z  40.718919 -114.043066      1305.1        0.0
# 4000  2024-11-06T23:45:54.59Z  40.718928 -114.042057      1301.6        0.0
# 4001  2024-11-06T23:45:55.40Z  40.718930 -114.041609      1300.2        0.0
# 4002  2024-11-06T23:45:56.02Z  40.718932 -114.041274      1299.4        0.0
# 4003  2024-11-06T23:45:57.80Z  40.718938 -114.040277      1297.1        0.0
# 4004  2024-11-06T23:45:58.40Z  40.718938 -114.039947      1296.3        0.0
# 4005  2024-11-06T23:46:00.02Z  40.718939 -114.039071      1294.6        0.0
# 4006  2024-11-06T23:46:01.60Z  40.718942 -114.038203      1293.9        0.0
# 4007  2024-11-06T23:46:02.20Z  40.718943 -114.037878      1293.9        0.0
# 4008  2024-11-06T23:46:03.80Z  40.718944 -114.037020      1293.4        0.0
# 4009  2024-11-06T23:46:04.39Z  40.718943 -114.036706      1293.4        0.0
# ...

# %%
df = pd.read_csv("./data/csv/7Nov24-flight5.csv")

df_landing = df[3836:3865]

plt.plot(df_landing["altitude_ft"])
plt.show()
plt.plot(df_landing["speed_kts"])
plt.show()

df_landing.to_csv("./data/csv/7Nov24-flight5-landing.csv")
df_landing
# Out:
#                     timestamp   latitude   longitude  altitude_m  acc_horiz  \
# 3836  2024-11-07T17:34:27.44Z  40.718947 -114.043499      1309.7        0.0
# 3837  2024-11-07T17:34:28.81Z  40.718952 -114.042669      1305.9        0.0
# 3838  2024-11-07T17:34:30.21Z  40.718950 -114.041834      1302.9        0.0
# 3839  2024-11-07T17:34:32.22Z  40.718946 -114.040647      1298.1        0.0
# 3840  2024-11-07T17:34:34.21Z  40.718945 -114.039473      1293.7        0.0
# 3841  2024-11-07T17:34:36.21Z  40.718943 -114.038334      1292.0        0.0
# 3842  2024-11-07T17:34:38.21Z  40.718950 -114.037233      1291.3        0.0
# 3843  2024-11-07T17:34:39.43Z  40.718956 -114.036602      1291.4        0.0
# 3844  2024-11-07T17:34:40.21Z  40.718958 -114.036199      1291.4        0.0
# 3845  2024-11-07T17:34:41.43Z  40.718961 -114.035623      1291.5        0.0
# 3846  2024-11-07T17:34:42.21Z  40.718963 -114.035258      1291.6        0.0
# ...
